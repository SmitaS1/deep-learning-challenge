# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns =['EIN','NAME'])
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type_val_count = application_df['APPLICATION_TYPE'].value_counts()
app_type_val_count
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_type_val_count[8:].index)
cutoff_value = 528

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_types = application_df['CLASSIFICATION'].value_counts()
classification_types
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classifications_cleaned = classification_types.loc[classification_types> 1]
classifications_cleaned
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_types.iloc[5:].index)
cutoff_value_classification = 1883

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Check the dataframe
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Check the data types for each column
application_df.dtypes
# Out:
# APPLICATION_TYPE          object
# AFFILIATION               object
# CLASSIFICATION            object
# USE_CASE                  object
# ORGANIZATION              object
# STATUS                     int64
# INCOME_AMT                object
# SPECIAL_CONSIDERATIONS    object
# ASK_AMT                    int64
# IS_SUCCESSFUL              int64
# dtype: object

# %%
# categorical_list will contain the names of all columns in application_df that have the data type "object", indicating they are categorical variables
categorical_list = application_df.dtypes[application_df.dtypes =="object"].index.tolist()
categorical_list
# Out:
# ['APPLICATION_TYPE',
#  'AFFILIATION',
#  'CLASSIFICATION',
#  'USE_CASE',
#  'ORGANIZATION',
#  'INCOME_AMT',
#  'SPECIAL_CONSIDERATIONS']

# %%
# Convert categorical data to numeric with `pd.get_dummies`
df_dummies = pd.get_dummies(application_df)
df_dummies.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                   False
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                  True                 False                False
# 1                 False                 False                 True
# 2                 False                 False                False
# 3                 False                 False                 True
# 4                 False                 False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                False                False                False  ...
# 1                False                False                False  ...
# 2                False                 True                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 44 columns]

# %%
# The code extracts the values of the column named 'IS_SUCCESSFUL' from the DataFrame application_df.
# Specifically, it retrieves the values in that column and returns them as a NumPy array.

application_df['IS_SUCCESSFUL'].values
# Out:
# array([1, 1, 0, ..., 0, 1, 0])

# %%
# Dropping IS_SUCCESSFUL column from application_df dataframe
df_new_application= application_df.drop(columns='IS_SUCCESSFUL')
df_new_application.values
# Out:
# array([['T10', 'Independent', 'C1000', ..., '0', 'N', 5000],
#        ['T3', 'Independent', 'C2000', ..., '1-9999', 'N', 108590],
#        ['T5', 'CompanySponsored', 'C3000', ..., '0', 'N', 5000],
#        ...,
#        ['T3', 'CompanySponsored', 'C2000', ..., '0', 'N', 5000],
#        ['T5', 'Independent', 'C3000', ..., '0', 'N', 5000],
#        ['T3', 'Independent', 'C1000', ..., '1M-5M', 'N', 36500179]],
#       dtype=object)

# %%
# Check to see the array value in df_dummies dataframe
df_dummies['IS_SUCCESSFUL'].values
# Out:
# array([1, 1, 0, ..., 0, 1, 0])

# %%
# Drop the column IS_SUCCESSFUL from the application_df dummy dataframe
df_clean_dummies = df_dummies.drop(columns='IS_SUCCESSFUL').values
df_clean_dummies
# Out:
# array([[1, 5000, False, ..., False, True, False],
#        [1, 108590, False, ..., False, True, False],
#        [1, 5000, False, ..., False, True, False],
#        ...,
#        [1, 5000, False, ..., False, True, False],
#        [1, 5000, False, ..., False, True, False],
#        [1, 36500179, False, ..., False, True, False]], dtype=object)

# %% [markdown]
# What variable(s) are the target(s) for your model?
#
# In this code snippet, the target variable for the model is IS_SUCCESSFUL, which is extracted from the df_dummies DataFrame and stored in the variable y. Therefore, IS_SUCCESSFUL is the target variable for the model.

# %% [markdown]
# What variable(s) are the feature(s) for your model?
#
# The features for the model are all the columns in the df_dummies DataFrame except for the target variable IS_SUCCESSFUL. These features are stored in the variable X. Therefore, the features for the model include all columns of df_dummies except IS_SUCCESSFUL.

# %%
# Split our preprocessed data into our features and target arrays
y= df_dummies['IS_SUCCESSFUL'].values
X= df_dummies.drop(columns='IS_SUCCESSFUL').values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# The code calculates the total number of input features in the training data (X_train),  which represents a single data point.
input_features_total = len(X_train[0])
input_features_total
# Out:
# 43

# %%
# Attempt 1.
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features_total = len(X_train[0])  # total number of features

hidden_nodes_layer1 = 8
hidden_nodes_layer2 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim = input_features_total, activation = "relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation = "relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation = "sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 352
#
#  dense_1 (Dense)             (None, 5)                 45
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 403 (1.57 KB)
# Trainable params: 403 (1.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy',optimizer='adam',metrics= ['accuracy'])

# %%
# The shape of a NumPy array represents its dimensions, the number of elements in the array.
print(y_train.shape)
# Out:
# (25724,)

# %%
# Train the model
fit_model =nn.fit(X_train_scaled,y_train,epochs =100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.6531 - accuracy: 0.6607
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5931 - accuracy: 0.7236
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5775 - accuracy: 0.7256
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5710 - accuracy: 0.7271
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5669 - accuracy: 0.7291
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5634 - accuracy: 0.7303
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5609 - accuracy: 0.7294
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5587 - accuracy: 0.7311
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5572 - accuracy: 0.7312
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5561 - accuracy: 0.7318
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5552 - accuracy: 0.7323
# Epoch 12/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5545 - accuracy: 0.7315
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5535 - accuracy: 0.7317
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5533 - accuracy: 0.7311
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5526 - accuracy: 0.7323
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5521 - accuracy: 0.7327
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5516 - accuracy: 0.7330
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5513 - accuracy: 0.7329
# Epoch 19/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5510 - accuracy: 0.7331
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5508 - accuracy: 0.7320
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5502 - accuracy: 0.7332
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5502 - accuracy: 0.7331
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5499 - accuracy: 0.7332
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5495 - accuracy: 0.7336
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5494 - accuracy: 0.7331
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5494 - accuracy: 0.7346
# Epoch 27/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5491 - accuracy: 0.7331
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5491 - accuracy: 0.7337
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5487 - accuracy: 0.7340
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5486 - accuracy: 0.7339
# Epoch 31/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5485 - accuracy: 0.7342
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5483 - accuracy: 0.7344
# Epoch 33/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5481 - accuracy: 0.7346
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5482 - accuracy: 0.7342
# Epoch 35/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5479 - accuracy: 0.7339
# Epoch 36/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5477 - accuracy: 0.7343
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7340
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5476 - accuracy: 0.7341
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5475 - accuracy: 0.7344
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5472 - accuracy: 0.7343
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5470 - accuracy: 0.7363
# Epoch 42/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5474 - accuracy: 0.7331
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5472 - accuracy: 0.7344
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5467 - accuracy: 0.7348
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5474 - accuracy: 0.7337
# Epoch 46/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5471 - accuracy: 0.7345
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5470 - accuracy: 0.7347
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5466 - accuracy: 0.7348
# Epoch 49/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5466 - accuracy: 0.7344
# Epoch 50/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5465 - accuracy: 0.7340
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5467 - accuracy: 0.7344
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5463 - accuracy: 0.7347
# Epoch 53/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5464 - accuracy: 0.7351
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7336
# Epoch 55/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5465 - accuracy: 0.7336
# Epoch 56/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5462 - accuracy: 0.7343
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5463 - accuracy: 0.7340
# Epoch 58/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5460 - accuracy: 0.7350
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7348
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7346
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7343
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5461 - accuracy: 0.7340
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5463 - accuracy: 0.7345
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5459 - accuracy: 0.7351
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5459 - accuracy: 0.7344
# Epoch 66/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5460 - accuracy: 0.7349
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5458 - accuracy: 0.7339
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5461 - accuracy: 0.7351
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7355
# Epoch 70/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5459 - accuracy: 0.7353
# Epoch 71/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5458 - accuracy: 0.7340
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5458 - accuracy: 0.7343
# Epoch 73/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5457 - accuracy: 0.7344
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5456 - accuracy: 0.7348
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5456 - accuracy: 0.7349
# Epoch 76/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5455 - accuracy: 0.7348
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5456 - accuracy: 0.7343
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5453 - accuracy: 0.7352
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5452 - accuracy: 0.7352
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5458 - accuracy: 0.7343
# Epoch 81/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5453 - accuracy: 0.7343
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5452 - accuracy: 0.7352
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7337
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5453 - accuracy: 0.7337
# Epoch 85/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5451 - accuracy: 0.7355
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5452 - accuracy: 0.7345
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7349
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7349
# Epoch 89/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5448 - accuracy: 0.7353
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7349
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5447 - accuracy: 0.7345
# Epoch 92/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5448 - accuracy: 0.7354
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7346
# Epoch 94/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5452 - accuracy: 0.7356
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7344
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7351
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5447 - accuracy: 0.7350
# Epoch 98/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5448 - accuracy: 0.7357
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7354
# Epoch 100/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5446 - accuracy: 0.7352

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5503 - accuracy: 0.7311 - 511ms/epoch - 2ms/step
# Loss: 0.5503498315811157, Accuracy: 0.7310787439346313

# %%
filepath = r"C:\Users\Shah_\Documents\Rutgers_Data_Science_Boot_Camp_Local\deep-learning-challenge21_to_Github\deep-learning-challenge\HS_files\AlphabetSoupCharity.h5"

nn.save(filepath)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Attempt 2
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features_total = len(X_train[0])  # total number of features

hidden_nodes_layer1 = 11
hidden_nodes_layer2 = 9

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=input_features_total))
nn.add(tf.keras.layers.LeakyReLU(alpha=0.2))  # Specify LeakyReLU activation function with alpha parameter

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2))
nn.add(tf.keras.layers.LeakyReLU(alpha=0.2))  # Specify LeakyReLU activation function with alpha parameter

# Output layer
nn.add(tf.keras.layers.Dense(units=1))
nn.add(tf.keras.layers.LeakyReLU(alpha=0.2))  # Specify LeakyReLU activation function with alpha parameter

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 11)                484
#
#  leaky_re_lu (LeakyReLU)     (None, 11)                0
#
#  dense_4 (Dense)             (None, 9)                 108
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 9)                 0
#
#  dense_5 (Dense)             (None, 1)                 10
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 1)                 0
#
# =================================================================
# Total params: 602 (2.35 KB)
# Trainable params: 602 (2.35 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy',optimizer='adam',metrics= ['accuracy'])

# %%
# Train the model
fit_model =nn.fit(X_train_scaled,y_train,epochs =50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5677 - accuracy: 0.7295
# Epoch 2/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5675 - accuracy: 0.7298
# Epoch 3/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5602 - accuracy: 0.7309
# Epoch 4/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5604 - accuracy: 0.7299
# Epoch 5/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5701 - accuracy: 0.7329
# Epoch 6/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5625 - accuracy: 0.7313
# Epoch 7/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5719 - accuracy: 0.7296
# Epoch 8/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5675 - accuracy: 0.7320
# Epoch 9/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5617 - accuracy: 0.7315
# Epoch 10/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5615 - accuracy: 0.7317
# Epoch 11/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5855 - accuracy: 0.7244
# Epoch 12/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5696 - accuracy: 0.7273
# Epoch 13/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5605 - accuracy: 0.7330
# Epoch 14/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5595 - accuracy: 0.7327
# Epoch 15/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5598 - accuracy: 0.7324
# Epoch 16/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5613 - accuracy: 0.7319
# Epoch 17/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5606 - accuracy: 0.7329
# Epoch 18/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5600 - accuracy: 0.7322
# Epoch 19/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5595 - accuracy: 0.7328
# Epoch 20/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5605 - accuracy: 0.7314
# Epoch 21/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5629 - accuracy: 0.7313
# Epoch 22/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5611 - accuracy: 0.7329
# Epoch 23/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5608 - accuracy: 0.7333
# Epoch 24/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5601 - accuracy: 0.7318
# Epoch 25/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5683 - accuracy: 0.7325
# Epoch 26/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5601 - accuracy: 0.7341
# Epoch 27/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5644 - accuracy: 0.7317
# Epoch 28/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5598 - accuracy: 0.7327
# Epoch 29/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5624 - accuracy: 0.7335
# Epoch 30/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5581 - accuracy: 0.7348
# Epoch 31/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5619 - accuracy: 0.7330
# Epoch 32/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5605 - accuracy: 0.7329
# Epoch 33/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5583 - accuracy: 0.7338
# Epoch 34/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5610 - accuracy: 0.7338
# Epoch 35/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5616 - accuracy: 0.7329
# Epoch 36/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5624 - accuracy: 0.7342
# Epoch 37/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5643 - accuracy: 0.7342
# Epoch 38/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5617 - accuracy: 0.7341
# Epoch 39/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5582 - accuracy: 0.7345
# Epoch 40/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5971 - accuracy: 0.7019
# Epoch 41/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5986 - accuracy: 0.6962
# Epoch 42/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5734 - accuracy: 0.7227
# Epoch 43/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5650 - accuracy: 0.7243
# Epoch 44/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5614 - accuracy: 0.7308
# Epoch 45/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5659 - accuracy: 0.7290
# Epoch 46/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5837 - accuracy: 0.7150
# Epoch 47/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5657 - accuracy: 0.7236
# Epoch 48/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5611 - accuracy: 0.7308
# Epoch 49/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5612 - accuracy: 0.7331
# Epoch 50/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5591 - accuracy: 0.7329

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5827 - accuracy: 0.7240 - 347ms/epoch - 1ms/step
# Loss: 0.5826610922813416, Accuracy: 0.7239649891853333

# %%
# Attempt 3
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features_total = len(X_train[0])  # total number of features

hidden_nodes_layer1 = 8
hidden_nodes_layer2 = 5
hidden_nodes_layer3 = 6
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=input_features_total, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 8)                 352
#
#  dense_7 (Dense)             (None, 5)                 45
#
#  dense_8 (Dense)             (None, 6)                 36
#
#  dense_9 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 440 (1.72 KB)
# Trainable params: 440 (1.72 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy',optimizer='adam',metrics= ['accuracy'])

# %%
# Train the model
fit_model =nn.fit(X_train_scaled,y_train,epochs =60)
# Out:
# Epoch 1/60
# 804/804 [==============================] - 3s 2ms/step - loss: 0.6055 - accuracy: 0.6960
# Epoch 2/60
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5660 - accuracy: 0.7244
# Epoch 3/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5592 - accuracy: 0.7302
# Epoch 4/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5559 - accuracy: 0.7310
# Epoch 5/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5537 - accuracy: 0.7312
# Epoch 6/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5522 - accuracy: 0.7308
# Epoch 7/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5508 - accuracy: 0.7315
# Epoch 8/60
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5502 - accuracy: 0.7307
# Epoch 9/60
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5496 - accuracy: 0.7320
# Epoch 10/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5494 - accuracy: 0.7320
# Epoch 11/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5487 - accuracy: 0.7324
# Epoch 12/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5484 - accuracy: 0.7330
# Epoch 13/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5482 - accuracy: 0.7331
# Epoch 14/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7329
# Epoch 15/60
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5473 - accuracy: 0.7330
# Epoch 16/60
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5470 - accuracy: 0.7324
# Epoch 17/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5469 - accuracy: 0.7322
# Epoch 18/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5467 - accuracy: 0.7325
# Epoch 19/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5466 - accuracy: 0.7332
# Epoch 20/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7330
# Epoch 21/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7345
# Epoch 22/60
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5458 - accuracy: 0.7323
# Epoch 23/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5455 - accuracy: 0.7343
# Epoch 24/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7343
# Epoch 25/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7343
# Epoch 26/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5453 - accuracy: 0.7334
# Epoch 27/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5452 - accuracy: 0.7343
# Epoch 28/60
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5451 - accuracy: 0.7345
# Epoch 29/60
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5449 - accuracy: 0.7344
# Epoch 30/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5449 - accuracy: 0.7339
# Epoch 31/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7341
# Epoch 32/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7341
# Epoch 33/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7346
# Epoch 34/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5445 - accuracy: 0.7331
# Epoch 35/60
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5444 - accuracy: 0.7338
# Epoch 36/60
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5445 - accuracy: 0.7344
# Epoch 37/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7341
# Epoch 38/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5443 - accuracy: 0.7343
# Epoch 39/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5443 - accuracy: 0.7353
# Epoch 40/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5442 - accuracy: 0.7346
# Epoch 41/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5443 - accuracy: 0.7343
# Epoch 42/60
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5441 - accuracy: 0.7341
# Epoch 43/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5438 - accuracy: 0.7354
# Epoch 44/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5441 - accuracy: 0.7343
# Epoch 45/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5438 - accuracy: 0.7346
# Epoch 46/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5437 - accuracy: 0.7345
# Epoch 47/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5436 - accuracy: 0.7340
# Epoch 48/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5437 - accuracy: 0.7340
# Epoch 49/60
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5434 - accuracy: 0.7342
# Epoch 50/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5436 - accuracy: 0.7352
# Epoch 51/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7354
# Epoch 52/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7352
# Epoch 53/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5436 - accuracy: 0.7347
# Epoch 54/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5436 - accuracy: 0.7342
# Epoch 55/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7352
# Epoch 56/60
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5433 - accuracy: 0.7336
# Epoch 57/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7354
# Epoch 58/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7352
# Epoch 59/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5432 - accuracy: 0.7360
# Epoch 60/60
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5431 - accuracy: 0.7356

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5550 - accuracy: 0.7276 - 459ms/epoch - 2ms/step
# Loss: 0.5550488233566284, Accuracy: 0.727580189704895

# %%
# Attempt 4.
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features_total = len(X_train[0])  # total number of features

hidden_nodes_layer1 = 8
hidden_nodes_layer2 = 5
hidden_nodes_layer3 = 6
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=input_features_total, activation="tanh"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="tanh"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="tanh"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))


# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 8)                 352
#
#  dense_11 (Dense)            (None, 5)                 45
#
#  dense_12 (Dense)            (None, 6)                 36
#
#  dense_13 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 440 (1.72 KB)
# Trainable params: 440 (1.72 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy',optimizer='adam',metrics= ['accuracy'])

# %%
# Train the model
fit_model =nn.fit(X_train_scaled,y_train,epochs =100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5979 - accuracy: 0.7020
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5688 - accuracy: 0.7235
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5614 - accuracy: 0.7255
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5579 - accuracy: 0.7281
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5551 - accuracy: 0.7310
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5533 - accuracy: 0.7314
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5518 - accuracy: 0.7320
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5507 - accuracy: 0.7320
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5502 - accuracy: 0.7317
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5497 - accuracy: 0.7318
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5492 - accuracy: 0.7321
# Epoch 12/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5488 - accuracy: 0.7315
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5486 - accuracy: 0.7320
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5482 - accuracy: 0.7329
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5480 - accuracy: 0.7331
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7328
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5473 - accuracy: 0.7335
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5470 - accuracy: 0.7341
# Epoch 19/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5468 - accuracy: 0.7334
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5468 - accuracy: 0.7334
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5465 - accuracy: 0.7341
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5463 - accuracy: 0.7330
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5463 - accuracy: 0.7333
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5461 - accuracy: 0.7338
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7345
# Epoch 26/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5457 - accuracy: 0.7346
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7330
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5453 - accuracy: 0.7345
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5452 - accuracy: 0.7365
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7345
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5452 - accuracy: 0.7346
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7346
# Epoch 33/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5451 - accuracy: 0.7345
# Epoch 34/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5446 - accuracy: 0.7341
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5447 - accuracy: 0.7357
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7353
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5446 - accuracy: 0.7346
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5446 - accuracy: 0.7352
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7352
# Epoch 40/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5445 - accuracy: 0.7348
# Epoch 41/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5442 - accuracy: 0.7352
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5442 - accuracy: 0.7350
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5441 - accuracy: 0.7351
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5441 - accuracy: 0.7350
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5438 - accuracy: 0.7355
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5438 - accuracy: 0.7360
# Epoch 47/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5436 - accuracy: 0.7365
# Epoch 48/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5439 - accuracy: 0.7357
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5437 - accuracy: 0.7357
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5438 - accuracy: 0.7351
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5437 - accuracy: 0.7359
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5436 - accuracy: 0.7359
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5436 - accuracy: 0.7358
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5436 - accuracy: 0.7360
# Epoch 55/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5435 - accuracy: 0.7363
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7360
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7353
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7360
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5432 - accuracy: 0.7361
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5432 - accuracy: 0.7362
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5431 - accuracy: 0.7357
# Epoch 62/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5430 - accuracy: 0.7357
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5431 - accuracy: 0.7359
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5428 - accuracy: 0.7363
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5425 - accuracy: 0.7374
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5427 - accuracy: 0.7352
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5427 - accuracy: 0.7374
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5427 - accuracy: 0.7366
# Epoch 69/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5428 - accuracy: 0.7368
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7376
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5425 - accuracy: 0.7377
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7368
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7373
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7376
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5425 - accuracy: 0.7371
# Epoch 76/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5423 - accuracy: 0.7371
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5425 - accuracy: 0.7364
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7371
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5422 - accuracy: 0.7362
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7367
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5422 - accuracy: 0.7367
# Epoch 82/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5420 - accuracy: 0.7362
# Epoch 83/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5420 - accuracy: 0.7365
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5419 - accuracy: 0.7366
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7360
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7359
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7376
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7366
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5420 - accuracy: 0.7371
# Epoch 90/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5417 - accuracy: 0.7367
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7362
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5419 - accuracy: 0.7367
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7368
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5416 - accuracy: 0.7368
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5419 - accuracy: 0.7370
# Epoch 96/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5420 - accuracy: 0.7372
# Epoch 97/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5417 - accuracy: 0.7370
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5419 - accuracy: 0.7370
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7369
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7367

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5565 - accuracy: 0.7258 - 464ms/epoch - 2ms/step
# Loss: 0.5565226078033447, Accuracy: 0.7258309125900269
